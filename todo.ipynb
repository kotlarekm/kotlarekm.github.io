# %% [markdown]
# # To do:
# - Struktura
# - Tytuł
# - Opis
# - Style css
# - Projekty:
#     - PowerBI
#         - PowerBI BI_NGO
#         - Analiza dla nowego sprzedawcy*
#         - Szkolenia*
#     - Python
#         - Spotify Analyzer
#         - Mieszkania
#         - Wyszukiwarka firm*
#     - SQL:
#         - Wyzwanie Wielkanocne

# %% [markdown]
# # Done:
# -
