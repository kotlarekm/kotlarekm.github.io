# %% [markdown]
# # To do:
#
# - Projekty:
#     - PowerBI
#         - Analiza dla nowego sprzedawcy*
#             - Nowe dane
#         - Szkolenia*
#             - Nowe dane
#             - Obróbka dashboardu
#     - Python
#         - Wyszukiwarka firm*
#     - SQL:
#         - Wyzwanie Wielkanocne
#             - dashboard

# %% [markdown]
# # Done:
# - Struktura
# - Tytuł
# - Opis
# - Style
# - Projekty:
#     - PowerBI
#         - PowerBI BI_NGO
#             -Repozytorium
#     - Python
#         - Spotify Analyzer
#         - Mieszkania
#     - SQL:
#         - Wyzwanie Wielkanocne
#             - repzytorium
